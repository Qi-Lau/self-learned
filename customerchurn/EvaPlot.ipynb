# %%
import matplotlib.pyplot as plt
import numpy as np


x = np.arange(0, 1, 0.0001)
y = np.arange(0, 1, 0.0001)

plt.xlabel("G-Means")
plt.ylabel("AUC")

# the values of classifiers on the five data sets respectively
a=[0.8131,0.4648,0.7868,0.6721,0.5175]
b=[0.91,0.521,0.8858,0.6786,0.5767]

x=[0.806,0.4629,0.7897,0.6728,0.525]
y=[0.9476,0.5384,0.9627,0.8217,0.6747]

m=[0.802,0.4649,0.7911,0.6735,0.5280]
n=[0.8894,0.5428,0.9254,0.8115,0.6676]

p=[0.7882,0.4576,0.7848,0.6652,0.5547]
q=[0.6869,0.4842,0.7391,0.5,0.6276]



plt.plot(a, b, 'yh', markersize=11)
plt.plot(x, y, 'bs', markersize=10)
plt.plot(m, n, 'rp', markersize=10)
plt.plot(p, q, 'gd', markersize=11)

#plt.plot(x, y, color="r", linestyle="--", marker="*", linewidth=1.0)

plt.legend(('Decision Tree', 'Random Forest', 'Adaboost', 'SVM'))

plt.title("Performance of Classifiers")

plt.show()
